# %%
price=1000
discount=0.2
final_price=price-(price*discount)
print("final price after discount:",final_price)
tax = final_price+(final_price*0.12)
print(tax)
# Out:
# final price after discount: 800.0
# 896.0

# %%
customer_name = "Rahul25"
age = 25
salary = 55000.75
is_fraud = False
print(customer_name)
# Out:
# Rahul25

# %%
# Customer details
age = 30
salary = 55000.0
loan_amount = 200000
existing_loan = 2
credit_score = 720
is_citizen = True

# %%
#---Arithmatic Opreators----
emi = loan_amount / 24   # Monthly installment
total_income_yearly = salary * 12
remaining_salary = total_income_yearly - (emi * 12)
print("Monthly EMI:",emi)
print("Yearly Income:",total_income_yearly)
print("Remaining Salary:",remaining_salary)
# Out:
# Monthly EMI: 8333.333333333334
# Yearly Income: 660000.0
# Remaining Salary: 560000.0

# %%
# ---Comparison Opreators ---
print("Is credit score good?", credit_score >= 700)
print("is EMI less Than 50% of salary?",emi< (salary * 0.5))
print("Is age less_than 60%?", age < 60)
# Out:
# Is credit score good? True
# is EMI less Than 50% of salary? True
# Is age less_than 60%? True

# %%
#---Logical Operator ---
eligible = (credit_score >= 700) and (emi < (salary * 0.5)) and (age < 60) and is_citizen
print("Loan Eligibility:", eligible)
# Out:
# Loan Eligibility: True

# %%
item1 = 1200
item2 = 800
item3 = 600
discount = 0.1
tax = 0.18
total_price = item1 + item2 + item3
final_price = total_price - (total_price * discount)
print("total Bill:", total_price)
print("final bill after discount:", final_price)
tax_amount = final_price * tax
print("tax amount:", tax_amount)
# Out:
# total Bill: 2600
# final bill after discount: 2340.0
# tax amount: 421.2

# %%
marks =int(input ("enter your marks:"))
if marks >= 95:
    print("grade: A+(outsanding)")
elif marks >= 90:
    print("grade: A (excellent)")
elif marks >= 80:
    print("grade: B (good)")
elif marks >= 70:
        print("grade: C (average)")
else:
  print("Fail")
# Out:
# enter your marks:70
# grade: C (average)

# %%
customer = ["Rahul","Priya","Amit","Sneha","Vikram"]
for name in customer:
    print("sending email to:", name)
# Out:
# sending email to: Rahul
# sending email to: Priya
# sending email to: Amit
# sending email to: Sneha
# sending email to: Vikram

# %%
for i in range(1, 6):
    print("reminder email number:", i)
# Out:
# reminder email number: 1
# reminder email number: 2
# reminder email number: 3
# reminder email number: 4
# reminder email number: 5

# %%
student = {"Rahul": 85,"priya": 70,"amit": 92}
for name, marks in student.items():
    if marks >= 95:
        grade = "A+"
    elif marks >= 90:
        grade = "A"
    elif marks >= 80:
        grade = "B"
    else:
        grade = "C"
    print(f"student: {name},marks:{marks},grade:{grade}")
# Out:
# student: Rahul,marks:85,grade:B
# student: priya,marks:70,grade:C
# student: amit,marks:92,grade:A

# %%
def great(name):
  print("hello",

# %%
def  money(x,y):
  total=x+y
  return total
money("1000","2000")
money("abc","xyz")
# Out:
# 'abcxyz'

# %%
#eligible for voting or not
def check_voting_eligibility(age):
  if age >=18:
    print("Eligible to vote")
  else:
    print("Not eligible to vote")
check_voting_eligibility(50)
# Out:
# Eligible to vote

# %%
#   function  to  issue books
def issue_books(student_name, books):
  print(f"\n{student_name} borrowed:")
  for book in books:
    print(f"- {book}")

# function to calculate fine
def calculate_fine(days_late):
  # Assuming a fine of 5 per day as `find_per_day` was undefined
  find_per_day = 5
  if days_late <= 5:
    return days_late * find_per_day
  else:
    # For days beyond 5, assume a higher fine or a different calculation.
    # For simplicity, let's keep the same rate, or adjust as needed.
    return days_late * find_per_day

# Function to generate report
def student_report(student_name, books, days_late):
    issue_books(student_name, books)
    fine = calculate_fine(days_late)
    print(f"Fine to be paid: ₹{fine}\n")

# Example usage
student_report("Rahul", ["Python Basics", "Data Science 101"], 3)
student_report("Priya", ["Machine Learning"], 0)
student_report("Amit", ["Advanced Python"], 7)
# Out:
# Rahul borrowed:
# - Python Basics
# - Data Science 101
# Fine to be paid: ₹15
#
#
# Priya borrowed:
# - Machine Learning
# Fine to be paid: ₹0
#
#
# Amit borrowed:
# - Advanced Python
# Fine to be paid: ₹35
